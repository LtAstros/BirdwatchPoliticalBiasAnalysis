# %%
import pandas as pd
import numpy as np
import os
from requests_oauthlib import OAuth1Session
import json
import constants

# %%
# Contains the API key information that will be needed for querying the Twitter API
# NOTE: You will need your own constants.py file with these two variables in it.
API_KEY_SEC = constants.API_KEY_SEC
API_KEY = constants.API_KEY

# %% [markdown]
# # Birdwatch Data Loader
# This file contains the process of getting all US English Tweets from the Birdwatch Program that were marked as misinformation. Data was obtained using the Birdwatch notes data from Twitter's website and using the Twitters APIs tweet endpoint.

# %%
birdwatch = pd.read_csv("./Data/notes-00000.tsv", sep="\t")

# %%
bool_idx = birdwatch["classification"] == "MISINFORMED_OR_POTENTIALLY_MISLEADING"
birdwatch = birdwatch.loc[bool_idx,["tweetId","classification","noteId"]]
birdwatch
# Out:
#                    tweetId                         classification  \
# 0      1377030478167937024  MISINFORMED_OR_POTENTIALLY_MISLEADING
# 2      1537080831751102467  MISINFORMED_OR_POTENTIALLY_MISLEADING
# 3      1537196168953974784  MISINFORMED_OR_POTENTIALLY_MISLEADING
# 4      1540087463099736065  MISINFORMED_OR_POTENTIALLY_MISLEADING
# 5      1535062308426510337  MISINFORMED_OR_POTENTIALLY_MISLEADING
# ...                    ...                                    ...
# 34245  1529939852028002329  MISINFORMED_OR_POTENTIALLY_MISLEADING
# 34246  1529939819878662177  MISINFORMED_OR_POTENTIALLY_MISLEADING
# 34247  1530481054015946754  MISINFORMED_OR_POTENTIALLY_MISLEADING
# 34248  1530480723953651712  MISINFORMED_OR_POTENTIALLY_MISLEADING
# 34251  1539138534564839424  MISINFORMED_OR_POTENTIALLY_MISLEADING
#
#                     noteId
# 0      1537142913737428992
# 2      1537147343715282945
# 3      1537204430730211328
# 4      1540422295029551104
# 5      1535128588818653184
# ...                    ...
# 34245  1530025194546413589
# 34246  1530026164777009175
# 34247  1530645389988319239
# 34248  1530646245865291777
# 34251  1539140492922966017
#
# [29939 rows x 3 columns]

# %%
# We are getting all the tweetIDs of the Misinformed Tweets to obtain their text
sample = birdwatch["tweetId"]

# %% [markdown]
# The Twitter API only allows for searching 100 tweets at a time in the form of a comma seperated string. Because of this, the following loop turns our sample into a list containing strings of 100 comma seperated IDs.

# %%
search_arr = []
# for i in range(10):
for i in range(birdwatch.shape[0]//100 + 1):
    search_str = ""
    tweet = sample[(i*100):(i*100 + 100)]
    for ele in tweet:
        search_str += str(ele) + ","
    search_str = search_str[:-1]
    search_arr += [search_str]

# %% [markdown]
# This code is Twitter's authentication code for python so it can largely be ignored
#
# **Source: https://github.com/twitterdev/Twitter-API-v2-sample-code/blob/main/Tweet-Lookup/get_tweets_with_user_context.py**

# %%
# To set your enviornment variables in your terminal run the following line:
consumer_key = API_KEY
consumer_secret = API_KEY_SEC

request_token_url = "https://api.twitter.com/oauth/request_token"
oauth = OAuth1Session(consumer_key, client_secret=consumer_secret)

try:
    fetch_response = oauth.fetch_request_token(request_token_url)
except ValueError:
    print(
        "There may have been an issue with the consumer_key or consumer_secret you entered."
    )

resource_owner_key = fetch_response.get("oauth_token")
resource_owner_secret = fetch_response.get("oauth_token_secret")
print("Got OAuth token: %s" % resource_owner_key)

# Get authorization
base_authorization_url = "https://api.twitter.com/oauth/authorize"
authorization_url = oauth.authorization_url(base_authorization_url)
print("Please go here and authorize: %s" % authorization_url)
verifier = input("Paste the PIN here: ")

# Get the access token
access_token_url = "https://api.twitter.com/oauth/access_token"
oauth = OAuth1Session(
    consumer_key,
    client_secret=consumer_secret,
    resource_owner_key=resource_owner_key,
    resource_owner_secret=resource_owner_secret,
    verifier=verifier,
)
oauth_tokens = oauth.fetch_access_token(access_token_url)


access_token = oauth_tokens["oauth_token"]
access_token_secret = oauth_tokens["oauth_token_secret"]

# Make the request
oauth = OAuth1Session(
    consumer_key,
    client_secret=consumer_secret,
    resource_owner_key=access_token,
    resource_owner_secret=access_token_secret,
)
# Out:
# Got OAuth token: Yn1TmwAAAAABcJlTAAABgd9OGzU
# Please go here and authorize: https://api.twitter.com/oauth/authorize?oauth_token=Yn1TmwAAAAABcJlTAAABgd9OGzU
# Paste the PIN here: 0540094

# %% [markdown]
# This code calls the API for each of the 100 tweet long strings in our list containing all of these strings. This then creates an array of dataframes that we can concatenate into one large dataframe. Note not all tweets are able to be obtained likely because of changed accessing rights on the tweet itself.
#
# We are also using twitter's expansions option to obtain location data on tweets in order to make sure they are in the US.

# %%
API_Tweets = []
API_Locations = []

for i in range((birdwatch.shape[0]//100) +1):
    params = {"ids": search_arr[i],"expansions": "geo.place_id","tweet.fields": "created_at,author_id,entities,lang","place.fields":"country"}
    response = oauth.get(
        "https://api.twitter.com/2/tweets", params=params
    )
    if response.status_code != 200:
        raise Exception(
            "Request returned an error: {} {}".format(response.status_code, response.text)
        )
    json_response = response.json()
    if any(list(map(lambda x: x.get("geo",False),json_response["data"]))):
        dataframed_response = pd.DataFrame(json_response["data"])[["id","entities","author_id","text","created_at",'lang','geo']]
        API_Tweets += [dataframed_response]
    if json_response.get("includes"):
        API_Locations += json_response["includes"]["places"]

# %%
tweet_locations = pd.DataFrame(API_Locations)[["country","id"]]
place_id_filter = {ele[0]: ele[1] for ele in list(zip(tweet_locations["id"],tweet_locations["country"]))}
# Out:
# {'f9c0877820b7848a': 'United States',
#  '1927193c57f35d51': 'United States',
#  '01fbe706f872cb32': 'United States',
#  '011add077f4d2da3': 'United States',
#  '319ee7b36c9149da': 'United States',
#  'dce44ec49eb788f5': 'United States',
#  '5e02a0f0d91c76d2': 'Turkey',
#  '084d0d0155787e9d': 'Ukraine',
#  '09d38e8e348e39ba': 'United States',
#  'd6819fe60643ebc1': 'United States',
#  '01a9a39529b27f36': 'United States',
#  'e4a0d228eb6be76b': 'United States',
#  '7325f3442fd87621': 'United States',
#  '2d83c71ce16cd187': 'United States',
#  '24181cf5031a5ef6': 'United States',
#  '5a110d312052166f': 'United States',
#  'e5797011cad97adf': 'United States',
#  'e564d30dc173d2a8': 'South Africa',
#  '5b02fa2a078d954a': 'Canada',
#  '480d6a1669a2f246': 'United States',
#  '17a83a55221b0671': 'United States',
#  '18810aa5b43e76c7': 'United States',
#  '04cb31bae3b3af93': 'United States',
#  'c3a6437e1b1a726d': 'Switzerland',
#  '00c39537733fa112': 'United States',
#  '317fcc4b21a604d5': 'India',
#  '3b77caf94bfc81fe': 'United States',
#  'e0060cda70f5f341': 'United States',
#  '813a485b26b8dae2': 'United States',
#  '1c69a67ad480e1b1': 'United States',
#  '10de09f288b1665c': 'United States',
#  'ac88a4f17a51c7fc': 'United States',
#  '44453d2ae8e47fd5': 'United States',
#  '3b98b02fba3f9753': 'United States',
#  '1305ff4bc7958000': 'Malaysia',
#  '741e9df4d2522275': 'United States',
#  '3b3916ee31cfc9e6': 'United States',
#  '94779fa8bb1f79a8': 'United States',
#  '7b1468a1d9713e3e': 'United States',
#  '5c62ffb0f0f3479d': 'United States',
#  '7b93be1d864cedbb': 'United States',
#  '300bcc6e23a88361': 'United States',
#  '1c73ebb264e145ee': 'United States',
#  '547fe91108bd744c': 'United States',
#  'a592bd6ceb1319f7': 'United States',
#  'd98e7ce217ade2c5': 'United States',
#  '4a9aecc7ad6b85e6': 'United States',
#  '5c43cbdfce4d3247': 'Canada',
#  '0019b30073d7f767': 'United States',
#  '00ab941b685334e3': 'United States',
#  '0022e3c837579650': 'New Zealand',
#  '74a9b3383262e5de': 'United States',
#  'db928fb47a6c40ca': 'United States',
#  'ce868cf1adf8c805': 'United States',
#  '01cace72701072d0': 'United States',
#  '2cb954ccdc0dba5f': 'United States',
#  '23a06e5cc6d83009': 'United States',
#  '9e707549d852ee6d': 'United States',
#  '96683cc9126741d1': 'United States',
#  '2526edd24c06e60c': 'United States',
#  '94965b2c45386f87': 'United States',
#  '00d5c62473ba713e': 'United States',
#  '8a927a7056322151': 'Botswana',
#  '0fc3a2d828d4c000': 'United States',
#  '3cf05613c1dd6dbd': 'United States',
#  '7142eb97ae21e839': 'United States',
#  'f97108ab3c4a42ed': 'United States',
#  '0c7c2d7e86f51e3b': 'United States',
#  '01b828da4311466f': 'United States',
#  'd32a345c8a9139c1': 'Saint Barthélemy',
#  '01c77c227d4ab0d5': 'United States',
#  '4303d1afc1e98c37': 'Russia',
#  '5e6cc87c609e3a59': 'United States',
#  '000c7ae04f0a875b': 'United States',
#  'dd3b100831dd1763': 'United States',
#  'fb26223d27a11fbb': 'United States',
#  '00c55f041e27dc51': 'United States',
#  '0121b92345f0e2b4': 'United States',
#  'd970e7fd69eaf4ec': 'United States',
#  '43d2418301bf1a49': 'United States',
#  'f0c327bab51d3d60': 'United States',
#  '472313ed153fe2bf': 'India',
#  'c3f37afa9efcf94b': 'United States',
#  '315906f3f5b4dffe': 'United Kingdom',
#  '2a93711775303f90': 'United States',
#  'dea1eac2d7ef8878': 'United States',
#  '55b4f9e5c516e0b6': 'United States',
#  '01bcc7ec66f06d60': 'United States',
#  'ecbe2aea853af44e': 'United States',
#  '0021184d617fff67': 'United States',
#  '29a119f18820c3ad': 'United States',
#  '3f5897b87d2bf56c': 'United States',
#  '0015cc0d71d49e19': 'United States',
#  '9a99329bbb5d8bba': 'United States',
#  '013379ee5729a5e6': 'United States',
#  'dd9c503d6c35364b': 'United States',
#  '4ec01c9dbc693497': 'United States',
#  '46cfc7fda28c4d88': 'Canada',
#  'fa3435044b52ecc7': 'United States',
#  '0fc2c89a22d55000': 'United States',
#  '864ff125241f172f': 'United States',
#  'ec6dac47648ca27f': 'United States',
#  'e8ad2641c1cb666c': 'United States',
#  '00f751614d8ce37b': 'United States',
#  '6613abf67d2b0d39': 'United States',
#  '5635c19c2b5078d1': 'United States',
#  '01b1e7677560ac06': 'United States',
#  '128ae72e3854b273': 'United States',
#  'd48f32df6ecc8aaa': 'United States',
#  '7dde0febc9ef245b': 'Ireland',
#  '009d3c3d41dbb00e': 'United States',
#  '0a0de7bd49ef942d': 'United States',
#  '19e2bff2e89dc38e': 'United States',
#  '2edb6e240797c549': 'Israel',
#  'b3a64b1b62d81d80': 'Japan',
#  '123d2dcb7ed77000': 'Indonesia',
#  '53b67b1d1cc81a51': 'United Kingdom',
#  '7a863bb88e5bb33c': 'United States',
#  '659477086d0d3485': 'United States',
#  '65b4760a2b411e11': 'United States',
#  '4265ece9285a2872': 'United States',
#  '8173485c72e78ca5': 'United States',
#  '1136a16503169000': 'United States',
#  '38ac902a28ee86da': 'India',
#  '7024b2f1414f7653': 'Germany',
#  'f98a7b4c97c21162': 'United States',
#  'bcd6f5a92e969e33': 'United States',
#  '01241e9666cacdd2': 'United States',
#  '9d8ae4b0fac2036a': 'Panama',
#  '6a0a3474d8c5113c': 'United States',
#  '6dbe9fce20d2ece4': 'United States',
#  '176cea42161e04b3': 'Canada',
#  'd374fb61a20fb74f': 'United States',
#  '27c45d804c777999': 'United States',
#  '4fd63188b772fc62': 'United States',
#  '33d41d156b557913': 'United States',
#  '599785cb8cd0515d': 'United States',
#  '005bdbe763d96c1d': 'United States',
#  '5669366953047e51': 'United States',
#  '01d5798f59d51d79': 'United States',
#  '006b48995ede9bcc': 'United States',
#  '227d358f6ed8d29e': 'United States'}

# %%
# Concat all of the returned tweet dataframes 
tweet_text = pd.concat(API_Tweets)
tweet_text = tweet_text.dropna(subset=["geo"])
# Author IDs needs to be numeric for merging purposes
tweet_text["author_id"] = tweet_text["author_id"].astype(int)
tweet_text["id"] = tweet_text["id"].astype(int)

# Get the hashtags from the entities dictionaries and convert it into a list of hashtage
tweet_text["hashtags"] = (tweet_text["entities"]
                          .apply(lambda x: [ele['tag'] for ele in x.get("hashtags",[])] if type(x) == dict else []))

# Get all of the value names from the geo dictionary inorder to make the columns
public_metrics_cols = list(tweet_text["geo"].iloc[0].keys())
public_metrics_cols

# Create the columns containing the geo data
for col in public_metrics_cols:
    tweet_text[col] = (tweet_text["geo"]
                           .apply(lambda x: x.get(col,0)))
    
tweet_text["country"] = tweet_text["place_id"].apply(lambda my_id: place_id_filter[my_id])
    
# Convert the created_at value to datetime
tweet_text["created_at"] = pd.to_datetime(tweet_text["created_at"])

# Drop the columns with dictionaries
tweet_text = tweet_text.drop(columns=["entities","geo","place_id"])
tweet_text = tweet_text.reset_index().drop(columns="index")
tweet_text = tweet_text.drop_duplicates(subset="id")

tweet_text.head()
# Out:
#                     id   author_id  \
# 0  1521300212412678144  2219695045
# 1  1521842639464648708  2234760798
# 2  1539244666385727489     9864482
# 3  1356597689480335361    21334179
# 4  1448979628882804746    59482886
#
#                                                 text  \
# 0  I haven’t seen Democrats this mad since the pa...
# 1  Stephen Colbert: “If these folks believe Roe w...
# 2  @AnupamChander Anupam, the fact that you’re so...
# 3  To everyone asking why this matters: If Psaki ...
# 4  And the big question?   Who is this Chinese ma...
#
#                  created_at lang                 hashtags        country
# 0 2022-05-03 01:26:49+00:00   en  [RoeOverturned, SCOTUS]  United States
# 1 2022-05-04 13:22:14+00:00   en                       []  United States
# 2 2022-06-21 13:51:40+00:00   en                       []  United States
# 3 2021-02-02 13:37:48+00:00   en                       []  United States
# 4 2021-10-15 11:50:38+00:00   en                       []  United States

# %%
birdwatch_tweets = birdwatch.merge(tweet_text,left_on="tweetId",right_on="id")
birdwatch_tweets = birdwatch_tweets[(birdwatch_tweets["lang"] == "en") & (birdwatch_tweets["country"] == "United States")]
birdwatch_tweets.head()
# Out:
#                tweetId                         classification  \
# 0  1521300212412678144  MISINFORMED_OR_POTENTIALLY_MISLEADING
# 1  1521842639464648708  MISINFORMED_OR_POTENTIALLY_MISLEADING
# 2  1521842639464648708  MISINFORMED_OR_POTENTIALLY_MISLEADING
# 3  1521842639464648708  MISINFORMED_OR_POTENTIALLY_MISLEADING
# 4  1539244666385727489  MISINFORMED_OR_POTENTIALLY_MISLEADING
#
#                 noteId                   id   author_id  \
# 0  1521630401508220928  1521300212412678144  2219695045
# 1  1521946220050018305  1521842639464648708  2234760798
# 2  1521943616905695235  1521842639464648708  2234760798
# 3  1521912043477078019  1521842639464648708  2234760798
# 4  1539458360386506752  1539244666385727489     9864482
#
#                                                 text  \
# 0  I haven’t seen Democrats this mad since the pa...
# 1  Stephen Colbert: “If these folks believe Roe w...
# 2  Stephen Colbert: “If these folks believe Roe w...
# 3  Stephen Colbert: “If these folks believe Roe w...
# 4  @AnupamChander Anupam, the fact that you’re so...
#
#                  created_at lang                 hashtags        country
# 0 2022-05-03 01:26:49+00:00   en  [RoeOverturned, SCOTUS]  United States
# 1 2022-05-04 13:22:14+00:00   en                       []  United States
# 2 2022-05-04 13:22:14+00:00   en                       []  United States
# 3 2022-05-04 13:22:14+00:00   en                       []  United States
# 4 2022-06-21 13:51:40+00:00   en                       []  United States

# %%
csv_file = birdwatch_tweets[["noteId","id","text","hashtags","classification"]]
csv_file.head()
# Out:
#                 noteId                   id  \
# 0  1521630401508220928  1521300212412678144
# 1  1521946220050018305  1521842639464648708
# 2  1521943616905695235  1521842639464648708
# 3  1521912043477078019  1521842639464648708
# 4  1539458360386506752  1539244666385727489
#
#                                                 text                 hashtags  \
# 0  I haven’t seen Democrats this mad since the pa...  [RoeOverturned, SCOTUS]
# 1  Stephen Colbert: “If these folks believe Roe w...                       []
# 2  Stephen Colbert: “If these folks believe Roe w...                       []
# 3  Stephen Colbert: “If these folks believe Roe w...                       []
# 4  @AnupamChander Anupam, the fact that you’re so...                       []
#
#                           classification
# 0  MISINFORMED_OR_POTENTIALLY_MISLEADING
# 1  MISINFORMED_OR_POTENTIALLY_MISLEADING
# 2  MISINFORMED_OR_POTENTIALLY_MISLEADING
# 3  MISINFORMED_OR_POTENTIALLY_MISLEADING
# 4  MISINFORMED_OR_POTENTIALLY_MISLEADING

# %%
csv_file[["id","text"]].drop_duplicates().to_csv("./Data/unique_tweets.csv",index=False)

# %%
pd.read_csv("./Data/unique_tweets.csv")
# Out:
#                       id                                               text
# 0    1521300212412678144  I haven’t seen Democrats this mad since the pa...
# 1    1521842639464648708  Stephen Colbert: “If these folks believe Roe w...
# 2    1539244666385727489  @AnupamChander Anupam, the fact that you’re so...
# 3    1356597689480335361  To everyone asking why this matters: If Psaki ...
# 4    1448979628882804746  And the big question?   Who is this Chinese ma...
# ..                   ...                                                ...
# 198  1475562179256471552  If you’re the President of the United States o...
# 199  1529427654839046144  I have news for the embarrassment that claims ...
# 200  1532710109201190912  More from Oak Park River Forest HS and its rac...
# 201  1539673370790436866  @greg_price11 Don’t blame lol companies. Biden...
# 202  1437525948497203201  WE THE PEOPLE DEMAND FAIR, SECURE, NON-CORRUPT...
#
# [203 rows x 2 columns]
